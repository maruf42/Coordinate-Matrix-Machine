# %%
import cloudpickle
from lib.xml_reader import read_xml_from_directory

# %%
filename = 'model.pkl'
pipeline = cloudpickle.load(open(filename, 'rb'))

# %%
test_xml = read_xml_from_directory('data')
result = pipeline.predict([test_xml])
result
# Out:
# {'prediction': ['Commonwealth Bank: CBA_DDA_E_IB_5_2',
#   'Empty Page: No Data',
#   'Additional Page: Previous Document'],
#  'confidence': [0.8205987170001301, 0.99, 0.0]}
